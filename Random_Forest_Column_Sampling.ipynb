# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_features=5, n_informative=5, n_redundant=0, n_clusters_per_class=1)
print(X.shape, y.shape)
# Out:
# (100, 5) (100,)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.905287 -1.701997  1.911420 -1.161459  1.446614       1
# 1 -1.635321  0.212338  0.258513 -2.130263  0.207819       1
# 2 -1.131337 -0.857387  2.581810 -0.058453  1.534254       1
# 3 -0.774284  0.329229  0.244114 -2.685632  0.052229       1
# 4 -2.259657  1.623896 -1.849265 -3.215975  0.422014       0

# %% [markdown]
# # **Function for feature Sampling**

# %%
import random
def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1], int(percent*(df.shape[1]-1)))
  new_df = df[cols]
  new_df['target'] = df['target']
  return new_df

# %%
df1 = sample_features(df,0.8)
df2 =sample_features(df,0.8)
df3 = sample_features(df,0.8)
# Out:
# /tmp/ipython-input-7-3778783950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
# /tmp/ipython-input-7-3778783950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
# /tmp/ipython-input-7-3778783950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1.shape
# Out:
# (100, 5)

# %%
df2.shape
# Out:
# (100, 5)

# %%
df3.shape
# Out:
# (100, 5)

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col2', 'col1', 'col4', 'col3', 'target'], dtype='object')
# Index(['col1', 'col3', 'col4', 'col5', 'target'], dtype='object')
# Index(['col5', 'col1', 'col4', 'col3', 'target'], dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:4],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,:4],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,:4],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
print(df1.head())
print(df2.head())
print(df3.head())
# Out:
#        col2      col1      col4      col3  target
# 0 -1.701997 -0.905287 -1.161459  1.911420       1
# 1  0.212338 -1.635321 -2.130263  0.258513       1
# 2 -0.857387 -1.131337 -0.058453  2.581810       1
# 3  0.329229 -0.774284 -2.685632  0.244114       1
# 4  1.623896 -2.259657 -3.215975 -1.849265       0
#        col1      col3      col4      col5  target
# 0 -0.905287  1.911420 -1.161459  1.446614       1
# 1 -1.635321  0.258513 -2.130263  0.207819       1
# 2 -1.131337  2.581810 -0.058453  1.534254       1
# 3 -0.774284  0.244114 -2.685632  0.052229       1
# 4 -2.259657 -1.849265 -3.215975  0.422014       0
#        col5      col1      col4      col3  target
# 0  1.446614 -0.905287 -1.161459  1.911420       1
# 1  0.207819 -1.635321 -2.130263  0.258513       1
# 2  1.534254 -1.131337 -0.058453  2.581810       1
# 3  0.052229 -0.774284 -2.685632  0.244114       1
# 4  0.422014 -2.259657 -3.215975 -1.849265       0

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.5666666666666667, 0.96875, 'x[3] <= 0.037\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.4, 0.90625, 'x[1] <= -0.641\ngini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.48333333333333334, 0.9375, 'True  '),
#  Text(0.3333333333333333, 0.84375, 'x[2] <= -1.058\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.26666666666666666, 0.78125, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.4, 0.78125, 'x[3] <= -0.41\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3333333333333333, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4666666666666667, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4666666666666667, 0.84375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7333333333333333, 0.90625, 'x[3] <= 3.654\ngini = 0.494\nsamples = 79\nvalue = [35, 44]'),
#  Text(0.6499999999999999, 0.9375, '  False'),
#  Text(0.6, 0.84375, 'x[0] <= -3.626\ngini = 0.481\nsamples = 72\nvalue = [29, 43]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.4, 0.9285714285714286, 'x[3] <= -0.495\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.13333333333333333, 0.7857142857142857, 'x[3] <= -0.705\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.26666666666666666, 0.8571428571428572, 'True  '),
#  Text(0.06666666666666667, 0.6428571428571429, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.2, 0.6428571428571429, 'x[0] <= 0.066\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13333333333333333, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26666666666666666, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.7857142857142857, 'x[0] <= -1.756\ngini = 0.397\nsamples = 66\nvalue = [18, 48]'),
#  Text(0.5333333333333333, 0.8571428571428572, '  False'),
#  Text(0.4666666666666667, 0.6428571428571429, 'x[3] <= 1.24\ngini = 0.477\nsamples = 28\nvalue = [17, 11]'),
#  Text(0.4, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.4, 0.9285714285714286, 'x[0] <= -0.495\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.13333333333333333, 0.7857142857142857, 'x[0] <= -0.705\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.26666666666666666, 0.8571428571428572, 'True  '),
#  Text(0.06666666666666667, 0.6428571428571429, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.2, 0.6428571428571429, 'x[0] <= -0.628\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13333333333333333, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26666666666666666, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6666666666666666, 0.7857142857142857, 'x[1] <= -1.756\ngini = 0.397\nsamples = 66\nvalue = [18, 48]'),
#  Text(0.5333333333333333, 0.8571428571428572, '  False'),
#  Text(0.4666666666666667, 0.6428571428571429, 'x[0] <= 1.24\ngini = 0.477\nsamples = 28\nvalue = [17, 11]'),
#  Text(0.4, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
# ...

# %%
clf1.predict(np.array([-0.857387, -1.131337, -0.058453 , 2.581810	]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-0.857387, -1.131337, -0.058453 , 2.581810	]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([-0.857387, -1.131337, -0.058453 , 2.581810	]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
