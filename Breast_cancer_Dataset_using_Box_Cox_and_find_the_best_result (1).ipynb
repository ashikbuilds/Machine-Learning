# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats #QQ plot

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PowerTransformer
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
df = pd.read_csv('/content/wdbc_converted.csv')
df.sample(5)
# Out:
#          ID Diagnosis  RadiusMean  TextureMean  PerimeterMean  AreaMean  \
# 234  882488         B       9.567        15.91          60.21     279.6
# 126  866083         M      13.610        24.69          87.76     572.6
# 292  891670         B      12.950        16.02          83.14     513.7
# 418  906024         B      12.700        12.17          80.88     495.0
# 159  871149         B      10.900        12.96          68.69     366.8
#
#      SmoothnessMean  CompactnessMean  ConcavityMean  ConcavePointsMean  ...  \
# 234         0.08464          0.04087        0.01652           0.016670  ...
# 126         0.09258          0.07862        0.05285           0.030850  ...
# 292         0.10050          0.07943        0.06155           0.033700  ...
# 418         0.08785          0.05794        0.02360           0.024020  ...
# 159         0.07515          0.03718        0.00309           0.006588  ...
#
#      RadiusWorst  TextureWorst  PerimeterWorst  AreaWorst  SmoothnessWorst  \
# 234        10.51         19.16           65.74      335.9           0.1504
# 126        16.89         35.64          113.20      848.7           0.1471
# 292        13.74         19.93           88.81      585.4           0.1483
# 418        13.65         16.92           88.12      566.9           0.1314
# 159        12.36         18.20           78.07      470.0           0.1171
#
#      CompactnessWorst  ConcavityWorst  ConcavePointsWorst  SymmetryWorst  \
# 234           0.09515         0.07161             0.07222         0.2757
# 126           0.28840         0.37960             0.13290         0.3470
# 292           0.20680         0.22410             0.10560         0.3380
# 418           0.16070         0.09385             0.08224         0.2775
# 159           0.08294         0.01854             0.03953         0.2738
#
#      FractalDimensionWorst
# 234                0.08178
# 126                0.07900
# 292                0.09584
# 418                0.09464
# 159                0.07685
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isnull().sum()
# Out:
# ID                       0
# Diagnosis                0
# RadiusMean               0
# TextureMean              0
# PerimeterMean            0
# AreaMean                 0
# SmoothnessMean           0
# CompactnessMean          0
# ConcavityMean            0
# ConcavePointsMean        0
# SymmetryMean             0
# FractalDimensionMean     0
# RadiusSE                 0
# TextureSE                0
# PerimeterSE              0
# AreaSE                   0
# SmoothnessSE             0
# CompactnessSE            0
# ConcavitySE              0
# ConcavePointsSE          0
# SymmetrySE               0
# FractalDimensionSE       0
# RadiusWorst              0
# TextureWorst             0
# PerimeterWorst           0
# AreaWorst                0
# SmoothnessWorst          0
# CompactnessWorst         0
# ConcavityWorst           0
# ConcavePointsWorst       0
# SymmetryWorst            0
# FractalDimensionWorst    0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID  RadiusMean  TextureMean  PerimeterMean     AreaMean  \
# count  5.690000e+02  569.000000   569.000000     569.000000   569.000000
# mean   3.037183e+07   14.127292    19.289649      91.969033   654.889104
# std    1.250206e+08    3.524049     4.301036      24.298981   351.914129
# min    8.670000e+03    6.981000     9.710000      43.790000   143.500000
# 25%    8.692180e+05   11.700000    16.170000      75.170000   420.300000
# 50%    9.060240e+05   13.370000    18.840000      86.240000   551.100000
# 75%    8.813129e+06   15.780000    21.800000     104.100000   782.700000
# max    9.113205e+08   28.110000    39.280000     188.500000  2501.000000
#
#        SmoothnessMean  CompactnessMean  ConcavityMean  ConcavePointsMean  \
# count      569.000000       569.000000     569.000000         569.000000
# mean         0.096360         0.104341       0.088799           0.048919
# std          0.014064         0.052813       0.079720           0.038803
# min          0.052630         0.019380       0.000000           0.000000
# 25%          0.086370         0.064920       0.029560           0.020310
# 50%          0.095870         0.092630       0.061540           0.033500
# 75%          0.105300         0.130400       0.130700           0.074000
# max          0.163400         0.345400       0.426800           0.201200
#
#        SymmetryMean  ...  RadiusWorst  TextureWorst  PerimeterWorst  \
# count    569.000000  ...   569.000000    569.000000      569.000000
# mean       0.181162  ...    16.269190     25.677223      107.261213
# std        0.027414  ...     4.833242      6.146258       33.602542
# min        0.106000  ...     7.930000     12.020000       50.410000
# 25%        0.161900  ...    13.010000     21.080000       84.110000
# 50%        0.179200  ...    14.970000     25.410000       97.660000
# 75%        0.195700  ...    18.790000     29.720000      125.400000
# max        0.304000  ...    36.040000     49.540000      251.200000
#
#          AreaWorst  SmoothnessWorst  CompactnessWorst  ConcavityWorst  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    880.583128         0.132369          0.254265        0.272188
# std     569.356993         0.022832          0.157336        0.208624
# min     185.200000         0.071170          0.027290        0.000000
# 25%     515.300000         0.116600          0.147200        0.114500
# 50%     686.500000         0.131300          0.211900        0.226700
# 75%    1084.000000         0.146000          0.339100        0.382900
# max    4254.000000         0.222600          1.058000        1.252000
#
#        ConcavePointsWorst  SymmetryWorst  FractalDimensionWorst
# count          569.000000     569.000000             569.000000
# mean             0.114606       0.290076               0.083946
# std              0.065732       0.061867               0.018061
# min              0.000000       0.156500               0.055040
# 25%              0.064930       0.250400               0.071460
# 50%              0.099930       0.282200               0.080040
# 75%              0.161400       0.317900               0.092080
# max              0.291000       0.663800               0.207500
#
# [8 rows x 31 columns]

# %%
X = df.drop(columns = ['Diagnosis'])
y = df.iloc[:,1]

# %%
X
# Out:
#            ID  RadiusMean  TextureMean  PerimeterMean  AreaMean  \
# 0      842302       17.99        10.38         122.80    1001.0
# 1      842517       20.57        17.77         132.90    1326.0
# 2    84300903       19.69        21.25         130.00    1203.0
# 3    84348301       11.42        20.38          77.58     386.1
# 4    84358402       20.29        14.34         135.10    1297.0
# ..        ...         ...          ...            ...       ...
# 564    926424       21.56        22.39         142.00    1479.0
# 565    926682       20.13        28.25         131.20    1261.0
# 566    926954       16.60        28.08         108.30     858.1
# 567    927241       20.60        29.33         140.10    1265.0
# 568     92751        7.76        24.54          47.92     181.0
#
#      SmoothnessMean  CompactnessMean  ConcavityMean  ConcavePointsMean  \
# 0           0.11840          0.27760        0.30010            0.14710
# 1           0.08474          0.07864        0.08690            0.07017
# 2           0.10960          0.15990        0.19740            0.12790
# 3           0.14250          0.28390        0.24140            0.10520
# 4           0.10030          0.13280        0.19800            0.10430
# ..              ...              ...            ...                ...
# 564         0.11100          0.11590        0.24390            0.13890
# 565         0.09780          0.10340        0.14400            0.09791
# 566         0.08455          0.10230        0.09251            0.05302
# 567         0.11780          0.27700        0.35140            0.15200
# 568         0.05263          0.04362        0.00000            0.00000
#
#      SymmetryMean  ...  RadiusWorst  TextureWorst  PerimeterWorst  AreaWorst  \
# 0          0.2419  ...       25.380         17.33          184.60     2019.0
# 1          0.1812  ...       24.990         23.41          158.80     1956.0
# 2          0.2069  ...       23.570         25.53          152.50     1709.0
# 3          0.2597  ...       14.910         26.50           98.87      567.7
# 4          0.1809  ...       22.540         16.67          152.20     1575.0
# ..            ...  ...          ...           ...             ...        ...
# 564        0.1726  ...       25.450         26.40          166.10     2027.0
# 565        0.1752  ...       23.690         38.25          155.00     1731.0
# 566        0.1590  ...       18.980         34.12          126.70     1124.0
# 567        0.2397  ...       25.740         39.42          184.60     1821.0
# 568        0.1587  ...        9.456         30.37           59.16      268.6
#
#      SmoothnessWorst  CompactnessWorst  ConcavityWorst  ConcavePointsWorst  \
# 0            0.16220           0.66560          0.7119              0.2654
# 1            0.12380           0.18660          0.2416              0.1860
# 2            0.14440           0.42450          0.4504              0.2430
# 3            0.20980           0.86630          0.6869              0.2575
# 4            0.13740           0.20500          0.4000              0.1625
# ..               ...               ...             ...                 ...
# 564          0.14100           0.21130          0.4107              0.2216
# 565          0.11660           0.19220          0.3215              0.1628
# 566          0.11390           0.30940          0.3403              0.1418
# 567          0.16500           0.86810          0.9387              0.2650
# 568          0.08996           0.06444          0.0000              0.0000
#
#      SymmetryWorst  FractalDimensionWorst
# 0           0.4601                0.11890
# 1           0.2750                0.08902
# 2           0.3613                0.08758
# 3           0.6638                0.17300
# 4           0.2364                0.07678
# ..             ...                    ...
# 564         0.2060                0.07115
# 565         0.2572                0.06637
# 566         0.2218                0.07820
# 567         0.4087                0.12400
# 568         0.2871                0.07039
#
# [569 rows x 31 columns]

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: Diagnosis, Length: 569, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = LogisticRegression()
clf.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
print("LR",accuracy_score(y_test,y_pred))
# Out:
# LR 0.9414893617021277

# %%
clf2 = DecisionTreeClassifier()
clf2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = clf2.predict(X_test)

# %%
print("DT",accuracy_score(y_test,y_pred2))
# Out:
# DT 0.9042553191489362

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
import numpy as np

# Encode string labels to numbers
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Use logistic regression (not linear regression)
clf = LogisticRegression(max_iter=1000)

# Accuracy instead of R² for classification
scores = cross_val_score(clf, X, y_encoded, scoring='accuracy', cv=5)
print("Cross-validated accuracy:", np.mean(scores))
# Out:
# Cross-validated accuracy: 0.9226362366092221

# %%
for col in X_train.columns:
  plt.figure(figsize=(14,4))
  plt.subplot(121)
  sns.distplot(X_train[col])
  plt.title(col)
  plt.subplot(122)
  stats.probplot(X_train[col], dist="norm", plot=plt)
  plt.title(col)
  plt.show()
# Out:
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# <ipython-input-53-4c765f82e371>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_transformed = scaler.fit_transform(X_train)
print(X_train_transformed.shape)
# Out:
# (381, 31)

# %%
pt=PowerTransformer(method = 'box-cox')

X_train_transformed = pt.fit_transform(X_train + 0.000001)
X_test_transformed = pt.transform(X_test + 0.000001)

pd.DataFrame({'cols':X_train.columns,'box_cox_lambdas':pt.lambdas_})
# Out:
#                      cols  box_cox_lambdas
# 0                      ID        -0.131819
# 1              RadiusMean        -0.624408
# 2             TextureMean        -0.006830
# 3           PerimeterMean        -0.630090
# 4                AreaMean        -0.291086
# 5          SmoothnessMean        -0.302199
# 6         CompactnessMean         0.085162
# 7           ConcavityMean         0.351846
# 8       ConcavePointsMean         0.386881
# 9            SymmetryMean        -0.361468
# 10   FractalDimensionMean        -2.578724
# 11               RadiusSE        -0.426099
# 12              TextureSE         0.015686
# 13            PerimeterSE        -0.439994
# 14                 AreaSE        -0.432205
# 15           SmoothnessSE        -0.418760
# 16          CompactnessSE         0.023446
# 17            ConcavitySE         0.370069
# 18        ConcavePointsSE         0.551541
# 19             SymmetrySE        -0.695938
# 20     FractalDimensionSE        -0.256841
# 21            RadiusWorst        -0.752042
# 22           TextureWorst         0.221650
# 23         PerimeterWorst        -0.694007
# 24              AreaWorst        -0.361779
# 25        SmoothnessWorst         0.085753
# 26       CompactnessWorst         0.174187
# 27         ConcavityWorst         0.435183
# 28     ConcavePointsWorst         0.542971
# 29          SymmetryWorst        -0.504453
# 30  FractalDimensionWorst        -1.240584

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score


le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)


clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_transformed, y_train_encoded)


y_pred = clf.predict(X_test_transformed)


print("Accuracy:", accuracy_score(y_test_encoded, y_pred))
# Out:
# Accuracy: 0.9787234042553191

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, PowerTransformer
import numpy as np


pt = PowerTransformer(method='box-cox')
X_transformed = pt.fit_transform(X + 1e-6)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

clf = LogisticRegression(max_iter=1000)
accuracy_scores = cross_val_score(clf, X_transformed, y_encoded, scoring='accuracy', cv=5)

print("Cross-validated accuracy:", np.mean(accuracy_scores))
# Out:
# Cross-validated accuracy: 0.9736531594472908

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PowerTransformer, LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd

# 1. Yeo-Johnson transform the features
pt1 = PowerTransformer()  # Yeo-Johnson by default
X_train_transformed2 = pt1.fit_transform(X_train)
X_test_transformed2 = pt1.transform(X_test)

# 2. Encode the target variable
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# 3. Fit a classification model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_transformed2, y_train_encoded)

# 4. Predict and evaluate
y_pred3 = clf.predict(X_test_transformed2)
print("Accuracy:", accuracy_score(y_test_encoded, y_pred3))

# 5. Show Yeo-Johnson lambdas
pd.DataFrame({'cols': X_train.columns, 'yeo_johnson_lambdas': pt1.lambdas_})
# Out:
# Accuracy: 0.9787234042553191
#                      cols  yeo_johnson_lambdas
# 0                      ID            -0.131823
# 1              RadiusMean            -0.739926
# 2             TextureMean            -0.061973
# 3           PerimeterMean            -0.647985
# 4                AreaMean            -0.293395
# 5          SmoothnessMean           -13.611312
# 6         CompactnessMean            -8.105419
# 7           ConcavityMean            -7.798918
# 8       ConcavePointsMean           -14.138846
# 9            SymmetryMean            -7.859974
# 10   FractalDimensionMean           -57.039999
# 11               RadiusSE            -3.644877
# 12              TextureSE            -0.849630
# 13            PerimeterSE            -0.956575
# 14                 AreaSE            -0.480661
# 15           SmoothnessSE          -175.575668
# 16          CompactnessSE           -35.609946
# 17            ConcavitySE           -21.586662
# 18        ConcavePointsSE           -53.741849
# 19             SymmetrySE           -74.522978
# 20     FractalDimensionSE          -272.246674
# 21            RadiusWorst            -0.859145
# 22           TextureWorst             0.191302
# 23         PerimeterWorst            -0.709808
# 24              AreaWorst            -0.363624
# 25        SmoothnessWorst            -6.632470
# 26       CompactnessWorst            -3.070580
# 27         ConcavityWorst            -1.751673
# 28     ConcavePointsWorst            -3.266136
# 29          SymmetryWorst            -5.780412
# 30  FractalDimensionWorst           -26.176816

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pt = PowerTransformer()
X_train_transformed = pt.fit_transform(X_train)
X_test_transformed = pt.transform(X_test)

# Step 3: Encode string labels (e.g., 'B' and 'M')
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Step 4: Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_transformed, y_train_encoded)

# Step 5: Predict and evaluate
y_pred = rf.predict(X_test_transformed)
accuracy = accuracy_score(y_test_encoded, y_pred)

print("Random Forest Accuracy:", accuracy)

# Optional: Show the lambdas from the PowerTransformer
pd.DataFrame({'cols': X_train.columns, 'yeo_johnson_lambdas': pt.lambdas_})
# Out:
# Random Forest Accuracy: 0.9627659574468085
#                      cols  yeo_johnson_lambdas
# 0                      ID            -0.131823
# 1              RadiusMean            -0.739926
# 2             TextureMean            -0.061973
# 3           PerimeterMean            -0.647985
# 4                AreaMean            -0.293395
# 5          SmoothnessMean           -13.611312
# 6         CompactnessMean            -8.105419
# 7           ConcavityMean            -7.798918
# 8       ConcavePointsMean           -14.138846
# 9            SymmetryMean            -7.859974
# 10   FractalDimensionMean           -57.039999
# 11               RadiusSE            -3.644877
# 12              TextureSE            -0.849630
# 13            PerimeterSE            -0.956575
# 14                 AreaSE            -0.480661
# 15           SmoothnessSE          -175.575668
# 16          CompactnessSE           -35.609946
# 17            ConcavitySE           -21.586662
# 18        ConcavePointsSE           -53.741849
# 19             SymmetrySE           -74.522978
# 20     FractalDimensionSE          -272.246674
# 21            RadiusWorst            -0.859145
# 22           TextureWorst             0.191302
# 23         PerimeterWorst            -0.709808
# 24              AreaWorst            -0.363624
# 25        SmoothnessWorst            -6.632470
# 26       CompactnessWorst            -3.070580
# 27         ConcavityWorst            -1.751673
# 28     ConcavePointsWorst            -3.266136
# 29          SymmetryWorst            -5.780412
# 30  FractalDimensionWorst           -26.176816

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import PowerTransformer, LabelEncoder

# Power transform features
pt = PowerTransformer()
X_train_transformed = pt.fit_transform(X_train)
X_test_transformed = pt.transform(X_test)

# Encode labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Random Forest with hyperparameter tuning
rf = RandomForestClassifier(random_state=42)

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],   # Number of trees
    'max_depth': [None, 10, 20, 30],    # Max depth of trees
    'min_samples_split': [2, 5, 10],    # Min samples to split
    'min_samples_leaf': [1, 2, 4],      # Min samples to be at a leaf node
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider at each split
    'bootstrap': [True, False]          # Whether to use bootstrap sampling
}

# Grid Search
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train_transformed, y_train_encoded)

# Best model from GridSearchCV
best_rf = grid_search.best_estimator_

# Predictions
y_pred = best_rf.predict(X_test_transformed)

# Evaluate
accuracy = accuracy_score(y_test_encoded, y_pred)
print(f"Optimized Random Forest Accuracy: {accuracy}")

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-6082c5e7d819> in <cell line: 0>()
#      29 # Grid Search
#      30 grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
# ---> 31 grid_search.fit(X_train_transformed, y_train_encoded)
#      32
#      33 # Best model from GridSearchCV
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1569     def _run_search(self, evaluate_candidates):
#    1570         """Search all candidates in param_grid"""
# -> 1571         evaluate_candidates(ParameterGrid(self.param_grid))
#    1572
#    1573
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:
