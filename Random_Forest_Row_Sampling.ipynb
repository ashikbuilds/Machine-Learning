# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_features=5, n_informative=5, n_redundant=0, n_clusters_per_class=1)
print(X.shape, y.shape)
# Out:
# (100, 5) (100,)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  2.195222  2.647902  1.910972 -1.088063 -1.012495       1
# 1  1.372821 -0.687929  1.290472  0.142491  0.039339       0
# 2  2.139207 -0.959361  2.206190  4.168813  1.455468       1
# 3  1.955928 -0.312389 -0.043960  1.621413 -1.448347       0
# 4  1.980546  2.470802  1.678168 -0.243944 -2.611225       1

# %% [markdown]
# # **Function for Row Sampling**

# %%
def sample_row(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
df1 = sample_row(df,0.1)
df2 = sample_row(df,0.1)
df3 = sample_row(df,0.1)

# %%
df1.shape
# Out:
# (10, 6)

# %%
df2.shape
# Out:
# (10, 6)

# %%
df3.shape
# Out:
# (10, 6)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= -0.175\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.75, 'x[4] <= 0.864\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.75, 'x[1] <= -0.556\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.625, 0.5, '  False')]

# %%
clf1.predict(np.array([2.195222,	2.647902,	1.910972,	-1.088063,	-1.012495	]).reshape(1,5))
# Out:
# array([1])

# %%
clf2.predict(np.array([2.195222,	2.647902,	1.910972,	-1.088063,	-1.012495	]).reshape(1,5))
# Out:
# array([0])

# %%
clf3.predict(np.array([2.195222,	2.647902,	1.910972,	-1.088063,	-1.012495	]).reshape(1,5))
# Out:
# array([1])
